# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/johnnybravo/opt/anaconda3/envs/lhl_env/lib/python3.9/site-packages (2.28.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/johnnybravo/opt/anaconda3/envs/lhl_env/lib/python3.9/site-packages (from requests) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/johnnybravo/opt/anaconda3/envs/lhl_env/lib/python3.9/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/johnnybravo/opt/anaconda3/envs/lhl_env/lib/python3.9/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/johnnybravo/opt/anaconda3/envs/lhl_env/lib/python3.9/site-packages (from requests) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries to use
import requests
import pandas as pd

# %%
#verify connectivity to the API
api_response_all = requests.get("https://api.citybik.es/v2/networks")
print(api_response_all)
api_response_selected_network = requests.get("https://api.citybik.es/v2/networks/biketown")
print(api_response_selected_network)
# Out:
# <Response [200]>
# <Response [200]>

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
#response in JSON format
response_json = api_response_selected_network.json()
print(response_json)
# Out:
# {'network': {'company': ['Portland Bureau of Transportation (PBOT)', 'Lyft Inc.'], 'gbfs_href': 'https://gbfs.biketownpdx.com/gbfs/gbfs.json', 'href': '/v2/networks/biketown', 'id': 'biketown', 'location': {'city': 'Portland, OR', 'country': 'US', 'latitude': 45.52175423291714, 'longitude': -122.68107935786247}, 'name': 'BIKETOWN', 'stations': [{'empty_slots': 2, 'extra': {'address': '1527, Southeast 47th Avenue, Richmond, Portland, Multnomah County, Oregon, 97215, United States of America', 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1674444927, 'renting': 1, 'returning': 1, 'slots': 3, 'uid': '1440914014488675490'}, 'free_bikes': 0, 'id': '2399b74c7c07d3a02e5e2a3e90460b7c', 'latitude': 45.51195046, 'longitude': -122.6141596, 'name': 'SE 47th at Hawthorne', 'timestamp': '2023-03-08T11:34:15.777000Z'}, {'empty_slots': 6, 'extra': {'address': '5024, Northeast Fremont Street, Rose City Park, Portland, Multnomah County, Oregon, 97213, United States of America', 'ebikes': 0, 'has_ebikes': True, 'last_updated': 1674444959, 'renting': 1, 'returning': 1, 'slots': 6, 'uid': '1440913864164819880'}, 'free_bikes': 0, 'id': 'e9aef274a3bf9dd43ff7e7f7352b250c', 'latitude': 45.54827571, 'longitude': -122.6111636, 'name': 'NE 50th at Fremont', 'timestamp': '2023-03-08T11:34:15.408000Z'}, {'empty_slots': 5, 'extra': {'address': 'Northeast Skidmore Street, Cully, Portland, Multnomah County, Oregon, 97218, United States of America', 'ebikes': 1, 'has_ebikes': True, 'last_updated': 1674444938, 'renting': 1, 'returning': 1, 'slots': 6, 'uid': '1440913894229591002'}, 'free_bikes': 1, 'id': '5037e02fd534d0164d7d2d8bcfcaa20c', 'latitude': 45.553917, 'longitude': -122.6020709, 'name': 'NE Cully at Skidmore', 'timestamp': '2023-03-08T11:34:15.677000Z'}, {'empty_slots': 2, 'extra': {'address': 'Red Square Cafe, 4505, Southeast Belmont Street, Hawthorne, Sunnyside, Portland, Multnomah County, Oregon, 97215, United States of America', 'ebikes': 1, 'has_ebikes': True, 'last_updated': 1674444978, 'renting': 1, 'returning': 1, 'slots': 3, 'uid': '1440914040258479302'}, 'free_bikes': 1, 'id': '97d7a7aeaf214cfedcf658e21189652b', 'latitude': 45.51658489, 'longitude': -122.6160378, 'name': 'SE Belmont at 45th', 'timestamp': '2023-03-08T11:34:15.730000Z'}, {'empty_slots': 1, 'extra': {'address': 'Gladstone Street Pizza, 3813, Southeast Gladstone Street, Creston-Kenilworth, Portland, Multnomah County, Oregon, 97202, United States of America', 'ebikes': 2, 'has_ebikes': True, 'last_updated': 1674444961, 'renting': 1, 'returning': 1, 'slots': 3, 'uid': '1440914010193708188'}, 'free_bikes': 2, 'id': 'ff54bba5b85cda833a23610dfc64fddc', 'latitude': 45.49333654, 'longitude': -122.6233971, 'name': 'SE 37th at Gladstone', 'timestamp': '2023-03-08T11:34:15.592000Z'}, {'empty_slots': 8, 'extra': {'address': "1238, Southeast Gideon Street, Ladd's Addition, Hosford-Abernethy, Portland, Multnomah County, Oregon, 97202, United States of America", 'ebikes': 2, 'has_ebikes': True, 'last_updated': 1674444938, 'renting': 1, 'returning': 1, 'slots': 10, 'uid': '1440914052404776192'}, 'free_bikes': 2, 'id': '4e47f8ec8affacbb3cf7a3eaa3a18bfd', 'latitude': 45.50280906, 'longitude': -122.6535398, 'name': 'SE Gideon at 12th Ave MAX station', 'timestamp': '2023-03-08T11:34:15.708000Z'}, {'empty_slots': 13, 'extra': {'address': 'Radish Underground, 414, Southwest 10th Avenue, Portland Downtown, Swan Island, Portland, Multnomah County, Oregon, 97205, United States of America', 'ebikes': 4, 'has_ebikes': True, 'last_updated': 1674444963, 'renting': 1, 'returning': 1, 'slots': 17, 'uid': '1440914073653690746'}, 'free_bikes': 4, 'id': 'c36ba913465bae461bf387f50ffa68b7', 'latitude': 45.52175423, 'longitude': -122.6810794, 'name': 'SW 10th at Harvey Milk', 'timestamp': '2023-03-08T11:34:15.549000Z'}, {'empty_slots': 14, 'extra': {'address': "Ladd's Addition Historic District, Southeast Hawthorne Boulevard, Central East Side, Buckman, Portland, Multnomah County, Oregon, 97214, United States  ...

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
#use list comprehension to load selected details into a pandas dataframe
stations = response_json["network"]["stations"]
rows = []
for station in stations:
    name = station["name"]
    latitude = station["latitude"]
    longitude = station["longitude"]
    free_bikes = station["free_bikes"]
    rows.append([name, latitude, longitude, free_bikes])
citybikes_results = pd.DataFrame(rows, columns = ["name", "latitude", "longitude", "free_bikes"])

display(citybikes_results)
# Out:
#                                            name   latitude   longitude  \
# 0                          SE 47th at Hawthorne  45.511950 -122.614160
# 1                            NE 50th at Fremont  45.548276 -122.611164
# 2                          NE Cully at Skidmore  45.553917 -122.602071
# 3                            SE Belmont at 45th  45.516585 -122.616038
# 4                          SE 37th at Gladstone  45.493337 -122.623397
# ..                                          ...        ...         ...
# 230                Urban Center Plaza at SW 6th  45.511583 -122.682281
# 231  SE 82nd Ave at SE Francis (Eastport Plaza)  45.494119 -122.578654
# 232                           Lone Fir Cemetery  45.518166 -122.639145
# 233          N Alberta Street at Interstate Ave  45.558918 -122.682400
# 234                SE 81st Ave at E Burnside St  45.522609 -122.580451
#
#      free_bikes
# 0             0
# 1             0
# 2             1
# 3             1
# 4             2
# ..          ...
# 230           0
# 231           0
# 232           0
# 233           2
# 234           3
#
# [235 rows x 4 columns]

# %%
#load dataframe data into a .CSV file
citybikes_results.to_csv('citybikes_results.csv', index=False)
